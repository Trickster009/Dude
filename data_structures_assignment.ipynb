# %% [markdown]
# # TASK 1

# %%
Products_List = ["Milk","Bread","Eggs","Sauce","Chips","Butter"]

# %%
Sample_Product_Tuple = ("Milk",30,"Dairy")

# %%
print(Products_List[1])
print(Products_List[-1])
# Out:
# Bread
# Butter

# %%
Products_List.append("Maggie")
Products_List.append("Curd")

# %%
print(Products_List)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Sauce', 'Chips', 'Butter', 'Maggie', 'Curd']

# %%
Sample_Product_List = list(Sample_Product_Tuple)
Sample_Product_List[1] = 40
Updated_Sample_Product_Tuple = tuple(Sample_Product_List)
print(Updated_Sample_Product_Tuple)
# Out:
# ('Milk', 40, 'Dairy')

# %%
print(type(Sample_Product_List))
print(type(Updated_Sample_Product_Tuple))
# Out:
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# # Task 2

# %%
Categories = set()
type(Categories)
# Out:
# set

# %%
Categories = {"Veg","NonVeg"}

# %%
Products_List
# Out:
# ['Milk', 'Bread', 'Eggs', 'Sauce', 'Chips', 'Butter', 'Maggie', 'Curd']

# %%
Categories.add("Dairy")
Categories
# Out:
# {'Dairy', 'NonVeg', 'Veg'}

# %%
check_category = "NonVeg"

exists = check_category in Categories
print(exists)
# Out:
# True

# %%
check_category = "Vegan"

exists = check_category in Categories
print(exists)
# Out:
# False

# %% [markdown]
# # TASK 3

# %%
price_dict ={"Milk":30,"Bread":40,"Eggs":50,"Sauce":60.5,"Chips":70.8,"Butter":80}

# %%
print(price_dict)
# Out:
# {'Milk': 30, 'Bread': 40, 'Eggs': 50, 'Sauce': 60.5, 'Chips': 70.8, 'Butter': 80}

# %%
type(price_dict)
# Out:
# dict

# %%
price_dict.update({"Jam":90})
price_dict
# Out:
# {'Milk': 30,
#  'Bread': 40,
#  'Eggs': 50,
#  'Sauce': 60.5,
#  'Chips': 70.8,
#  'Butter': 80,
#  'Jam': 90}

# %%
price_dict.update({"Milk":35})
price_dict
# Out:
# {'Milk': 35,
#  'Bread': 40,
#  'Eggs': 50,
#  'Sauce': 60.5,
#  'Chips': 70.8,
#  'Butter': 80,
#  'Jam': 90}

# %%
index = "Chips"

if index in price_dict:
    del price_dict[index]

print(price_dict)
# Out:
# {'Milk': 35, 'Bread': 40, 'Eggs': 50, 'Sauce': 60.5, 'Butter': 80, 'Jam': 90}

# %%
index = "Chips"
price_dict.pop(index, None) 
print(price_dict)
# Out:
# {'Milk': 35, 'Bread': 40, 'Eggs': 50, 'Sauce': 60.5, 'Butter': 80, 'Jam': 90}

# %%
sum = 0
ctr = 0
for i in price_dict.values():
    sum += i
    ctr +=1
avg = sum/ctr
print(avg)
# Out:
# 59.25

# %% [markdown]
# # Task 4

# %%
Products_List = ["Milk","Bread","Eggs","Sauce","Butter","Jam"]
print(Products_List)
print(price_dict)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Sauce', 'Butter', 'Jam']
# {'Milk': 35, 'Bread': 40, 'Eggs': 50, 'Sauce': 60.5, 'Butter': 80, 'Jam': 90}

# %%
veg_products ={"Milk", "Bread", "Sauce", "Butter", "Jam"}
non_veg_products = {"Eggs"}

catalog = []

for product in Products_List:
    price = price_dict.get(product)
    
    if product in veg_products:
        category="Veg"
    else:
        category= "NonVeg"
    
    catalog.append((product, price, category))

print(catalog)
# Out:
# [('Milk', 35, 'Veg'), ('Bread', 40, 'Veg'), ('Eggs', 50, 'NonVeg'), ('Sauce', 60.5, 'Veg'), ('Butter', 80, 'Veg'), ('Jam', 90, 'Veg')]

# %%
category_to_products = {}

for product, price, category in catalog:
    if category not in category_to_products:
        category_to_products[category] = []
    category_to_products[category].append(product)

print(category_to_products)
# Out:
# {'Veg': ['Milk', 'Bread', 'Sauce', 'Butter', 'Jam'], 'NonVeg': ['Eggs']}

# %%
Products=category_to_products.get("Veg")
Products
# Out:
# ['Milk', 'Bread', 'Sauce', 'Butter', 'Jam']

# %%
ctr = 0
Products = []

for key in category_to_products:
   
    Products=category_to_products.get(key)
    prev_ctr = len(Products)
    
    if ctr < prev_ctr:
        ctr=prev_ctr
        New_Product = Products

New_Product
# Out:
# ['Milk', 'Bread', 'Sauce', 'Butter', 'Jam']
